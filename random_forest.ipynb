# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

from ipynb.fs.defs.Naive_bayes import categorical_enconding

# %%
credit = pd.read_csv("../Credit.csv") ; credit.head(3)
# Out:
#   checking_status  duration                    credit_history    purpose  \
# 0              <0         6  'critical/other existing credit'   radio/tv
# 1        0<=X<200        48                   'existing paid'   radio/tv
# 2   'no checking'        12  'critical/other existing credit'  education
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
# 1           5951                <100     1<=X<4                       2
# 2           2096                <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 0         'male single'          none  ...       'real estate'  67
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 2         'male single'          none  ...       'real estate'  49
#
#    other_payment_plans housing existing_credits                   job  \
# ...

# %%
#database split

class_ = credit['class']
attb = credit.drop('class', axis=1)

#categorical enconding
attb = categorical_enconding(attb)

#train test split
X_train, X_test, Y_train, Y_test = train_test_split(attb, class_,random_state=0, train_size = 0.7)

#model selection
random_forest = RandomForestClassifier(n_estimators=100) #defines the number of decision trees that will be constructed in the model

#model training 
random_forest.fit(X_train, Y_train)

#test
Y_predict = random_forest.predict(X_test)

#accuracy check
acc = accuracy_score(Y_test,Y_predict)
acc
# Out:
# 0.7833333333333333

# %%
confusion_mat = confusion_matrix(Y_test,Y_predict)
confusion_mat
# Out:
# array([[ 41,  45],
#        [ 20, 194]], dtype=int64)

# %%
random_forest.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=198121219),
#  DecisionTreeClassifier(max_features='sqrt', random_state=741917507),
#  DecisionTreeClassifier(max_features='sqrt', random_state=931683751),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1523960907),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2022034751),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1702213810),
#  DecisionTreeClassifier(max_features='sqrt', random_state=204318175),
#  DecisionTreeClassifier(max_features='sqrt', random_state=968951433),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1458935646),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2120565536),
#  DecisionTreeClassifier(max_features='sqrt', random_state=58265235),
#  DecisionTreeClassifier(max_features='sqrt', random_state=27522896),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1426702026),
# ...
